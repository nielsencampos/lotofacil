# %%
import psycopg
import pandas
from itables import init_notebook_mode

# %%
init_notebook_mode(all_interactive=True)

# %%
conn = psycopg.connect("postgresql://lotofacil:lotofacil@localhost:5432/lotofacil")
df = pandas.read_sql("select * from silver.dim_municipality order by 1, 2", conn)

# %%
df
